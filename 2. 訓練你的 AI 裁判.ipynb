# %% [markdown]
# <img src="https://www.10botics.com/images/logo_website_700x200-300x86.png" width="300"/>

# %% [markdown]
# # 🤖 第二步：訓練你的 AI 裁判 (Teachable Machine)
#
# 在這個步驟中，我們要教電腦看懂什麼是「剪刀、石頭、布」。我們不需要寫複雜的程式，只需要使用 Google 的工具就能完成！
#
# ---
#
# ## 🟢 1. 建立專案
# 1.  開啟瀏覽器，前往 [Teachable Machine 網站](https://teachablemachine.withgoogle.com/train)。
# 2.  點選 **"Image Project" (影像專案)**。
# 3.  選擇 **"Standard Image Model" (標準影像模型)**。
# <br>
#     <img src="image/create_new_project.png" width="700" />
# ---
#
# ## 📷 2. 收集數據 (Data Collection)
# **這是最重要的步驟！** 你的照片拍得越好，AI 就會越聰明。請依照下方設定三個類別：
# <br>
#     <img src="image/change_class name.png" width="700" />
#
# ### 📄 類別 1: Paper (布)
# * **動作**：對著鏡頭比出布。
# * **數量**：50 - 100 張。
# * **技巧**：手指張開，手心朝向鏡頭。
# <br>
#     <img src="image/paper.png" width="700" />
#
# ### ✂️ 類別 2: Scissors (剪刀)
# * **動作**：對著鏡頭比出剪刀。
# * **數量**：50 - 100 張。
# * **技巧**：剪刀的形狀比較複雜，記得要多換幾個角度。
# <br>
#     <img src="image/scissors.png" width="700" />
#
# ### 🪨 類別 3: Rock (石頭)
# * **動作**：對著鏡頭比出石頭。
# * **數量**：50 - 100 張。
# * **技巧**：手腕轉一轉，讓鏡頭看到不同角度的石頭（正面、側面、遠一點、近一點）。
#
# ### 🚫 類別 4: None (背景/沒人)
# * **⚠️ 關鍵技巧**：這是為了讓 AI 知道「現在沒人在玩」長什麼樣子。
# * **動作**：**人離開鏡頭**，只錄背景畫面。
# * **數量**：50 - 100 張。。
# <br>
#     <img src="image/rock_and_none.png" width="700" />
#
# ---
#
# ## 🧠 3. 訓練模型 (Training)
# 1.  按下中間的 **"Train Model" (訓練模型)** 按鈕。
# 2.  **請勿關閉或切換分頁**，這需要一點時間（約 1~2 分鐘）。
# <br>
#     <img src="image/train_model.png" width="700" />
# 3.  訓練完成後，在右側的 "Preview" (預覽) 視窗試玩看看，確認 AI 能準確辨認你的手勢。
# <br>
#     <img src="image/test_model.png" width="700" />
#
# ---
#
# ## 📥 4. 匯出模型 (Export Model)
# 我們要把訓練好的「大腦」下載下來，準備放進 Raspberry Pi。
#
# 1.  點擊右側的 **"Export Model"** 按鈕。
# 2.  上方分頁選擇 **"TensorFlow Lite"**。
# 3.  下方格式選擇 **"Quantized" (量化)**。
#     * *為什麼？* 量化模型體積小、速度快，最適合 Raspberry Pi。
# 4.  點擊 **"Download my model"**。
# <br>
#     <img src="image/export_model.png" width="700" />
#
# ---
#
# ## ✅ 5. 檢查檔案
# 下載並解壓縮後，請確認你有以下兩個檔案：
# 1.  `model.tflite` (模型本體)
# 2.  `labels.txt` (標籤檔，告訴程式 0 1 2 3 是甚麼)

# %% [markdown]
# <hr/>

# %% [markdown]
# ## Congratulation! You have finished this chapter.

# %% [markdown]
# This jupyter notebook is created by 10Botics. <br>
# For permission to use in school, please contact info@10botics.com <br>
# All rights reserved. 2024.
